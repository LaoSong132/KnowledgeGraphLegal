# %% [markdown]
# ## Convert Patterns to Fake Legal Sentences

# %%
import pandas as pd
import re
from collections import defaultdict
from pathlib import Path
import pathlib
import time
import random

# %%
# initialising primes and cache them
def isPrime(x):
    count = 0
    for i in range(int(x/2)):
        if x % (i+1) == 0:
            count = count+1
    return count == 1

MIN_PRIME = 0
MAX_PRIME = 1000

CACHED_PRIMES = [i for i in range(MIN_PRIME, MAX_PRIME) if isPrime(i)]

# %%
# CHANGE_ME BLOCK
# Change Me_1
INPUT_FILE = r'../PATTERNS/CASE_LAW_COUNSEL/GROUP_MODEL_TEMPLATE_PATTERN_COUNSEL_CL_SEP_BATCH_v3.xlsx'


# Change Me_2
MODEL_PATTERN_SHEET = 'ModelPatterns'
NAMED_ENTITIES_SHEET = 'NamedEntities'

VAL_TEST_SKIP_STEP = 3 # take every 3rd sentence into validation and test data

# Change Me_3
CORPUS_DIR_PATH = r'../PATTERNS/CORPUS_GROUPS'
#CORPUS_DIR_PATH = r'../PATTERNS/CORPUS_EXAMPLE'

# Change Me_4
PATTERN_GROUP_LIST = ['G1', 'G2','G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9',
                    'G10', 'G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 
                    'G18', 'G19', 'G20', 'G21', 'G22', 'G23', 'G24', 'G25', 'G26']
#PATTERN_GROUP_LIST = ['G1']
#PATTERN_GROUP_LIST = ['G2']
#PATTERN_GROUP_LIST = ['G18']

# Change Me_5
#MINI_BATCH_SIZE = 64
MINI_BATCH_SIZE = 16
BATCHES_PER_FILE = 3 # MINI_BATCH_SIZE * BATCHES_PER_FILE sentences for each pattern
# Set RANDOM_STATE to a fix prime value for reproducibale results
RANDOM_STATE = random.choice([i for i in CACHED_PRIMES if MIN_PRIME < i < MAX_PRIME])
print(RANDOM_STATE)
# Out:
# 647

# %%
#from datetime import datetime
#dt = datetime.now()
#dt.microsecond

# %%
TOKENIZATION_STRING = r"[^\s\t,!\"()\*\+,-.\/:;?@\[\]\\`\{\|\}¶§·¸ʺ‶‟”“˗„\']+|[,!\"()\*\+,-.\/:;?@\[\]\\`\{\|\}¶§·¸ʺ‶‟”“˗„\']"
TOKENIZER = re.compile(TOKENIZATION_STRING)
LABEL_TYPE = 'ner'
OTHER = "other" # default unsupported entity_tag

def custom_tokenizer(sentence):
    if type(sentence) == float: return ""
    if len(sentence) == 0: return ""    
    tokens = [match.group() for match in TOKENIZER.finditer(sentence)]
    return tokens

def fix_tokenization(sentence):
    if type(sentence) == float: return ""
    if len(sentence) == 0: return ""
    new_sentence = ' '.join(custom_tokenizer(sentence))
    return new_sentence

sent = "' A. Douglas Brady, Jr., Judge of the Superior Court .'"
new_sent = ' '.join(custom_tokenizer(sent))
print(new_sent)

def get_entity_code_df_dict():
    """Maps each EntityCode to a df that stores dictionary data for this EntityCode."""
    dict_files = NER_DF.DictionaryFileName.unique()
    ec_df_dict = {}
    for dict_file in dict_files:
        file_path = f'../DICTIONARIES/{dict_file}'
        dict_df = pd.read_excel(file_path)
        print(f'{dict_df.shape} : {dict_file}')
        df = NER_DF[NER_DF.DictionaryFileName == dict_file]
        entity_code_list = list(df.EntityCode.unique())
        for code in entity_code_list:
            ec_df_dict [code] = dict_df
            
    return ec_df_dict

def print_list(obj_list):
    for obj in obj_list: 
        print(obj)
        print('~'*30)
# Out:
# ' A . Douglas Brady , Jr . , Judge of the Superior Court . '

# %%
def get_entity(token):
    """If token is EntityCode then extract entity code (e.g., ATTORNEY) and return True to indicate it is EntityCode.
        Else: return token as is and False as an indicator that it is not EntityCode
    """
    open_angle = '<' in token
    close_angle = '>' in token
    end = len(token)
    if open_angle and close_angle:
        return token[1:end-1], True
    else: return token, False
    
def is_exception_entity(entity):
    entity_splits = entity.split()
    if len(entity_splits) > 1: return True
    else: return False

def get_entity_base(entity_phrase):
    """Remove numeric suffix from the entity name to get the base.
    Check if entity is an ExceptionEntityName: Law Office of <ATTORNEY_2>.
    ASSUMPTION: that entity_phrase contains exactly ONE <base_entity>.
    Example: LAW_FIRM_5 has the base LAW_FIRM
    """
    
    entity_splits = entity_phrase.split()
    for item in entity_splits:
        entity, is_base = get_entity(item)
        if is_base: break
            
    entity_splits = entity.split('_')
    last = entity_splits[-1]
    base = entity
    if last.isnumeric(): # LAW_FIRM_1, LAW_FIRM_2
        base = "_".join(entity_splits[0:-1])        
        
    return base
        
def get_entity_tag(entity, entity_type, supported=True):
    """Extract entity base (e.g., LAW_FIRM_3 has the base LAW_FIRM).
    Use ner dictionary (NER_DICT) look-up to determine the entity tag for the base.
    Ex: entity_base = LAW_FIRM, entity_tag = lawFirm
    """
    entity_tag = OTHER
    entity_base = get_entity_base(entity)
    
    if entity_type:
        entity_tag = NER_DICT[entity_base]['EntityTag']
        if supported: # account for entity being supported or not for tagging
            is_supported = NER_DICT[entity_base]['isSupported']
            if not is_supported: entity_tag = OTHER

    return entity_tag

def ner_parse_pattern(pattern):
    """Given the pattern, return a list of (token, ner_tag) pairs.
    Example: 
    """
    master_list = []
    token_list = custom_tokenizer(pattern)
    for token in token_list:
        entity, entity_type = get_entity(token)
        entity_tag = get_entity_tag(entity, entity_type, supported=False)
        master_list.append((entity, entity_tag))
    return master_list


def get_exceptions_dict(pdf, pattern):
    sp_dict = {}
    for _, row in pdf.iterrows():
        entity = row.ExceptionEntityName
        entity_tag = row.ExceptionEntityTag
        for pos in range(len(pattern)):
            if pattern.startswith(entity, pos):
                sp_dict[pos] = (entity, entity_tag)
    return sp_dict

def get_exceptions_ner_list(sp_dict, pattern):
    master_list = []
    pos_list = list(sp_dict.keys())
    pos_list.sort(reverse=False)
    
    start = 0
    for pos in pos_list:
        entity = sp_dict[pos][0]
        tag = sp_dict[pos][1]
        if start < pos:
            prec_pattern = pattern[start:pos]
            prec_list = ner_parse_pattern(prec_pattern)
            for item in prec_list:
                master_list.append(item)
                
        master_list.append((entity, tag))
        start = pos + len(entity)
    
    if start < len(pattern):
        tail_pattern = pattern[start:len(pattern)]
        tail_list = ner_parse_pattern(tail_pattern)
        for item in tail_list:
            master_list.append(item)
                
    return master_list
    
def ner_parse_pattern_df(pdf):
    """Given the df with exceptions in ExceptionEntityName for pattern handling, 
    return a list of (token, ner_tag) pairs."""
    
    pattern = pdf.iloc[0].PATTERN
    
    # split pattern into sub-patterns based on the exceptions
    # defined in the ExceptionEntityName column
    sp_dict = get_exceptions_dict(pdf, pattern)
    print('~'*30)
    print(sp_dict)
    master_list = get_exceptions_ner_list(sp_dict, pattern)
    
    return master_list
    

def get_sample_name_list(base, replace = True, how_many=64, random_state=RANDOM_STATE, fixed = False):
    """Sample with replacement; otherwise, may not have enough names to sample.""" 
    if not fixed: random_state = random.choice([i for i in CACHED_PRIMES if MIN_PRIME < i < MAX_PRIME])
    df = ENTITY_CODE_DF_DCT[base]
    ser = df[base]
    ser.dropna(inplace = True) # critical, as the excel files are of uneven row numbers per column
    name_list = list(ser.sample(n=how_many, replace=True, random_state=random_state).values)
    return name_list    

def get_fake_entity_names(token, tag, how_many):
    """Given (token, tag) pair, generate how_many instances of fake entity names.
    Example: (ATTORNEY_1, attorney) will have a list of how_many names to use as a
    fake substitute for ATTORNEY_1
    """
    base = get_entity_base(token)
    entity_name_list = get_sample_name_list(base, replace = True, how_many=how_many, random_state=RANDOM_STATE, fixed = False)
    
    if not is_exception_entity(token): return entity_name_list
    else: # Special Cases such as Law Office of <ATTORNEY_2>: assume only one <entity>
        token_list = []
        
        parts = token.split()
        entity_name = []
        
        prefix_pos = token.find('<')
        suffix_pos = token.find('>') + 1
        
        prefix = token[0:prefix_pos]
        suffix = token[suffix_pos:]
        
        for entity in entity_name_list:
            new_entity = ' '.join(entity.split())
            final_token = prefix.strip() + ' ' + new_entity.strip() + ' ' + suffix.strip()
            token_list.append(final_token.strip())
        return token_list
        
def generate_fake_sentences(ner_token_list, how_many = MINI_BATCH_SIZE):
    unique_entity_list = get_unique_entity_list(ner_token_list)
    fake_entity_dict = defaultdict(list)
    master_fake_list = []
    
    for (token, tag) in unique_entity_list:
        key = (token, tag)
        entity_name_list = get_fake_entity_names(token, tag, how_many=how_many)
        fake_entity_dict[key] = entity_name_list
    
    for idx in range(0, how_many):
        fake_list = []
        for (token, tag) in ner_token_list:
            key = (token, tag)
            if key in fake_entity_dict.keys():
                entity_names = fake_entity_dict[key]
                name = entity_names[idx]
                fake_list.append((name, tag))
            else: fake_list.append((token, tag))
            
        master_fake_list.append(fake_list)
        
    return master_fake_list

def get_unique_entity_list(ner_token_list):
    """Extract unique (ENTITY, EntityTag) pairs in the sentence template"""
    entity_list = []
    result_list = []
    for (token, tag) in ner_token_list:
        if tag != OTHER:
            entity_list.append((token, tag))
    if len(entity_list):
        entity_set = set(entity_list)
        result_list = list(entity_set)
    return result_list

# %%
# Test the function
#entity_phrase = 'Office of <ATTORNEY_2> Law Firm'
#base = get_entity_base(entity_phrase)
#print (base)
#entity_name_list = get_fake_entity_names(token=entity_phrase, tag='lawFirm', how_many=1)
#print(entity_name_list)

# %%
from collections import defaultdict
def process_non_special_patterns(pg_list = PATTERN_GROUP_LIST, 
                                 merge = False, pattern_src = "cl_counsel", 
                                 conll=True):
    """For a given pattern groupID from the pg_list, generate fake sentences and save them in conll format.
    merge = True : combine output into a single file for different groupIDs
    merge = False: do not combine into a single conll file
    """
    
    pattern_sent_dict = defaultdict(list)
    print(len(pg_list), " : The Number of Pattern Groups to Process.")
    for pattern_group in pg_list:
        print("="*50)
        print(pattern_group, ": Processing this pattern group")
        df = NON_SPECIAL_PATTERN_DF [NON_SPECIAL_PATTERN_DF.GroupID == pattern_group]
        pattern_list = df.PATTERN.unique()
        print(pattern_group, ": The Number of Unique Patterns : ", len(pattern_list))
                      
        file_prefix = pattern_group
        if merge: file_prefix = '_'.join(pg_list)
    
        file_names = [f'{file_prefix}_{pattern_src}_train_iobes.txt', 
                      f'{file_prefix}_{pattern_src}_val_iobes.txt',
                      f'{file_prefix}_{pattern_src}_test_iobes.txt']
        
        # Validation and Test data set do not have to be large for each pattern.
        # Taking only every third sentence might suffice.
        file_skip_dict = {file_names[0]:1, file_names[1]:VAL_TEST_SKIP_STEP, file_names[2]:VAL_TEST_SKIP_STEP} # how many sentences to skip
                      
        no_files = len(file_names)
        how_many = MINI_BATCH_SIZE * no_files * BATCHES_PER_FILE
        print('HOW MANY = ', how_many) # 384 = 64 * 3 * 2

        for pid, pattern in enumerate(pattern_list):
            print('='*30)
            print(pattern_group, ": ", pid, ": PATTERN TEMPLATE: \n\t", pattern)
            print('-'*30)
            ner_token_list = ner_parse_pattern(pattern)
            print(ner_token_list)
            print(pid, '\tNER TOKEN LIST: ', ner_token_list)
            
        
            fake_tokenized_sent_list = generate_fake_sentences(ner_token_list, how_many=how_many)
            #print(pid, '\tFAKE TOKENIZED SENTENCE LIST:', fake_tokenized_sent_list)
            pattern_sent_dict[pattern] = fake_tokenized_sent_list
            
            if conll:
                print(len(fake_tokenized_sent_list), ' fake sentences per file and per pattern')
                start = 0
                sent_per_file = len(fake_tokenized_sent_list) // no_files
                print(pid, "\tPreparing CONLL file format for writing...")
                for file_name in file_names:
                    print(pid, "\t",file_name)
                    end = start + sent_per_file
                    skip = file_skip_dict[file_name]
                    conll_text = convert_fake_sent_to_CONLL_sentence(fake_tokenized_sent_list[start:end:skip])
                    write_to_conll_file(conll_text,  file_name,  dir_path=CORPUS_DIR_PATH, mode="a", verbose = False)
                    start = end
                    
    return pattern_sent_dict
                

def process_special_patterns(pg_list = PATTERN_GROUP_LIST, 
                             merge = False, pattern_src = "cl_counsel", 
                             conll=True):
    """For a given pattern groupID from the pg_list, generate fake sentences and save them in conll format.
    merge = True : combine output into a single file for different groupIDs
    merge = False: do not combine into a single conll file
    """
    print(len(pg_list), " : The Number of Pattern Groups to Process.")
    pattern_sent_dict = defaultdict(list)
    
    for pattern_group in pg_list:
        print("="*50)
        print(pattern_group, ": Processing this pattern group")        
        
        df = SPECIAL_PATTERN_DF [SPECIAL_PATTERN_DF.GroupID == pattern_group]
        pattern_list = df.PATTERN.unique()
        print(pattern_group, ": The Number of Unique Patterns : ", len(pattern_list))
                      
        file_prefix = pattern_group
        if merge: file_prefix = '_'.join(pg_list)
    
        file_names = [f'{file_prefix}_{pattern_src}_train_iobes.txt', 
                      f'{file_prefix}_{pattern_src}_val_iobes.txt',
                      f'{file_prefix}_{pattern_src}_test_iobes.txt']
        
        # Validation and Test data set do not have to be large for each pattern.
        # Taking only every third sentence might suffice.
        file_skip_dict = {file_names[0]:1, file_names[1]:VAL_TEST_SKIP_STEP, file_names[2]:VAL_TEST_SKIP_STEP} # how many sentences to skip        
                      
        no_files = len(file_names)
        how_many = MINI_BATCH_SIZE * no_files * BATCHES_PER_FILE
        print('HOW MANY = ', how_many) # 384 = 64 * 3 * 2

        for pid, pattern in enumerate(pattern_list):
            print('='*30)
            print(pattern_group, ": ", pid, ": PATTERN TEMPLATE: \n\t", pattern)
            print('-'*30)
            
            pdf = df[df.PATTERN == pattern]
            
            ner_token_list = ner_parse_pattern_df(pdf)
            print(pid, '\tNER TOKEN LIST: ', ner_token_list)
        
            fake_tokenized_sent_list = generate_fake_sentences(ner_token_list, how_many=how_many)
            #print(pid, '\tFAKE TOKENIZED SENTENCE LIST:', fake_tokenized_sent_list)
            pattern_sent_dict[pattern] = fake_tokenized_sent_list
            
            if conll:
                print(len(fake_tokenized_sent_list), ' fake sentences per file and per pattern')
                start = 0
                sent_per_file = len(fake_tokenized_sent_list) // no_files
                print(pid, "\tPreparing CONLL file format for writing...")
                for file_name in file_names:
                    print(pid, "\t",file_name)
                    end = start + sent_per_file
                    skip = file_skip_dict[file_name]
                    conll_text = convert_fake_sent_to_CONLL_sentence(fake_tokenized_sent_list[start:end:skip])
                    write_to_conll_file(conll_text,  file_name,  dir_path=CORPUS_DIR_PATH, mode="a", verbose = False)
                    start = end
                
    return pattern_sent_dict

# %%
# CONLL-related methods
def process_entity_segment(entity, entity_tag):
    token_list = entity.strip().split()
    if len(token_list) == 1:
        single_text = entity + ' S-' + entity_tag + '\n'
        return single_text
    
    B_tag = ' B-' + entity_tag + '\n'
    I_tag = ' I-' + entity_tag + '\n'
    E_tag = ' E-' + entity_tag + '\n'
    
    B_text = token_list[0] + B_tag
    E_text = token_list[-1] + E_tag
    I_text = ""
    for token in token_list[1:len(token_list)-1]:
        I_text = I_text + token + I_tag
        
    return B_text + I_text + E_text    

def process_other_segment(token):
    text = ""
    
    O_tag = " O" + '\n'
    token_list = token.strip().split()
    for token in token_list:
        text = text + token + O_tag
    return text

def get_conll_tag(entity_tag):
    df = NER_DF[NER_DF.isSupported == True]
    status = entity_tag in list(df.EntityTag)
    if status: return entity_tag
    else: return OTHER
    
def convert_fake_sent_to_CONLL_sentence(fake_tokenized_sent_list):
    text = ""
    
    for ner_token_list in fake_tokenized_sent_list:
        for idx, (token, tag) in enumerate(ner_token_list):
            conll_tag = get_conll_tag(tag)
            if conll_tag == OTHER: 
                conll_token = process_other_segment(token.strip())
                text = text + conll_token
            else: text = text + process_entity_segment(token.strip(), conll_tag)
        text = text + '\n'

    return text

def write_to_conll_file(text, file_name="conll_iobes.txt", dir_path=CORPUS_DIR_PATH, mode = 'a', verbose = False):
    path = pathlib.Path(dir_path)
    abs_path = path.absolute()
    if not abs_path.exists():
        abs_path.mkdir()
    file_path = abs_path.joinpath(file_name)
        
    with open(file_path, mode, encoding = "utf-8") as the_file:
        the_file.write(text)
        
    if verbose: print("Saved: ", file_path)
    return

# %% [markdown]
# ### Step-1: Read and Filter Model Pattern File

# %%
MODEL_PATTERN_DF = pd.read_excel(INPUT_FILE, sheet_name = MODEL_PATTERN_SHEET)
NER_DF = pd.read_excel(INPUT_FILE, sheet_name = NAMED_ENTITIES_SHEET)
NER_DF.tail(7)
# Out:
#         Category        EntityCode        EntityTag  isSupported Example  \
# 21      Location        STATE_ABBR            state        False  Calif.
# 22      Location            COUNTY           county        False     NaN
# 23        Person            PERSON           person        False     NaN
# 24        Person  PERSON_LAST_NAME           person        False     NaN
# 25    Employment         GOV_TITLE  employmentTitle        False     NaN
# 26  Organization            PRISON           prison        False     NaN
# 27  Organization            CHURCH           church        False     NaN
#
#             DictionaryFileName     ToDo
# 21  US_state_abbrev_names.xlsx      NaN
# 22  US_county_state_names.xlsx      NaN
# 23           person_names.xlsx      NaN
# 24           person_names.xlsx  ADD_COL
# 25   US_employment_titles.xlsx      NaN
# 26        US_organization.xlsx      NaN
# 27        US_organization.xlsx      NaN

# %%
MODEL_PATTERN_DF.head()
# Out:
#      PID  Reviewed    SME  isSpecial  DataError ExceptionEntityName  \
# 0  FP_23     False   True      False        1.0                 NaN
# 1   M_96     False  False      False        0.0                 NaN
# 2   M_99      True   True      False        0.0                 NaN
# 3  M_100      True   True      False        0.0                 NaN
# 4  M_102      True   True      False        0.0                 NaN
#
#   ExceptionEntityTag  isFinal GroupID PATTERN  \
# 0                NaN    False     NaN     NaN
# 1                NaN    False     NaN     NaN
# 2                NaN    False     NaN     NaN
# 3                NaN    False     NaN     NaN
# 4                NaN    False     NaN     NaN
#
#                                   PRE_FILLED_PATTERN  \
# 0  ELIZABETH LATIF , Law Offices of For <LITIGANT...
# 1  For <STATE_NAME=Alabama> Department of Public ...
# 2  For <LITIGANT_PERSON> , Secretary of U . S . D...
# 3  For <LITIGANT_PERSON> , Acting Commissioner , ...
# 4  For <LITIGATN_PERSON> , Commissioner of Social...
#
#                                        Sentence_TEXT Sentence_ID
# 0  ELIZABETH LATIF , Law Offices of For Defendant...         S29
# 1  For Alabama Department of Public Health , Denn...        S132
# 2  For ALEX M . AZAR II , Secretary of U . S . De...        S135
# 3  For Andrew M . Saul , Acting Commissioner , So...        S136
# 4  For Andrew M . Saul , Commissioner of Social S...        S138

# %%
ENTITY_CODE_DF_DCT = get_entity_code_df_dict()
# Out:
# (61002, 10) : US_litigants.xlsx
# (61002, 2) : US_attorney_names.xlsx
# (218, 7) : US_law_firms.xlsx
# (28889, 2) : US_cities_state_names.xlsx
# (1, 2) : US_cities_abbrev_names.xlsx
# (51, 3) : US_state_abbrev_names.xlsx
# (3241, 2) : US_county_state_names.xlsx
# (61002, 7) : person_names.xlsx
# (30, 1) : US_employment_titles.xlsx
# (6, 2) : US_organization.xlsx

# %%
ENTITY_CODE_DF_DCT.keys()
# Out:
# dict_keys(['LITIGANT_PERSON', 'LITIGANT_COMPANY', 'LITIGANT_COUNTY', 'LITIGANT_CHURCH', 'LITIGANT_HOSPITAL', 'LITIGANT_INSURANCE_CO', 'LITIGANT_FOUNDATION', 'LITIGANT_ROLE', 'GOV_LITIGANT', 'LITIGANT_LAW_FIRM', 'ATTORNEY', 'LAW_FIRM', 'ODD_LAW_FIRM', 'UNIQUE_LAW_FIRM', 'GOVT_ORG_AS_LAW_FIRM', 'AMICUS_CURAE_LAW_FIRM', 'FOUNDATION_LAW_FIRM', 'CITY', 'CITY_ABBR', 'STATE', 'STATE_NAME', 'STATE_ABBR', 'COUNTY', 'PERSON', 'PERSON_LAST_NAME', 'GOV_TITLE', 'PRISON', 'CHURCH'])

# %%
ENTITY_CODE_DF_DCT['LITIGANT_ROLE'].LITIGANT_ROLE[0:10]
# Out:
# 0                 APPELLANT
# 1                 Appellant
# 2                 appellant
# 3                APPELLANTS
# 4                Appellants
# 5                appellants
# 6    APPELLANT / PETITIONER
# 7    Appellant / Petitioner
# 8    appellant / petitioner
# 9    APPELLANT - PETITIONER
# Name: LITIGANT_ROLE, dtype: object

# %%
ENTITY_CODE_DF_DCT['LAW_FIRM'].head()
# Out:
#                                          LAW_FIRM  \
# 0      Traub Lieberman Straus and Shrewsberry LLP
# 1                     Joseph , Aleem & Slowik LLC
# 2                                 Lowe and Reilly
# 3  Foland , Wickens , Roper , Hofer & Crawford PC
# 4                                     AKERMAN LLP
#
#                          UNIQUE_LAW_FIRM                ODD_LAW_FIRM  \
# 0  Pacific Merchant Shipping Association  AARP Foundation Litigation
# 1         Office of Disciplinary Counsel             Adams and Reese
# 2         Social Security Administration         AKERMAN SENTERFITT
# 3           State Public Defender Office   AKERMAN SENTERFITT EIDSON
# 4                                    NaN     Akin Gump
#
#                        FOUNDATION_LAW_FIRM  \
# 0              ACLU of Oklahoma Foundation
# 1                     FREEDOM  FOUNDATION
# 2  Freedom  from  Religion  Foundation
# 3             Hindu  American  Foundation
# 4              Pacific  Legal  Foundation
#
#                       AMICUS_CURAE_LAW_FIRM  \
# 0                      FREEDOM  FOUNDATION
# 1   Freedom  from  Religion  Foundation
# 2                          GENDER  JUSTICE
# 3              Hindu  American  Foundation
# 4             Institute  for  Free  Speech
#
#                                 GOVT_ORG_AS_LAW_FIRM  \
# 0               United States Department of Justice
# 1  Office of Immigration Litigation , Department ...
# 2  U . S . Department of Justice , Civil Division...
# 3  United States Department of Justice , Office o...
# 4  U . S . Department of Justice , Office of Immi...
#
#                                LawFirmPattern
# 0  Law Office of <ATTORNEY> , Attorney at Law
# 1   The Law Offices of <ATORNEY> , <ATTORNEY>
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN

# %%
MODEL_PATTERN_DF.head()
# Out:
#      PID  Reviewed    SME  isSpecial  DataError ExceptionEntityName  \
# 0  FP_23     False   True      False        1.0                 NaN
# 1   M_96     False  False      False        0.0                 NaN
# 2   M_99      True   True      False        0.0                 NaN
# 3  M_100      True   True      False        0.0                 NaN
# 4  M_102      True   True      False        0.0                 NaN
#
#   ExceptionEntityTag  isFinal GroupID PATTERN  \
# 0                NaN    False     NaN     NaN
# 1                NaN    False     NaN     NaN
# 2                NaN    False     NaN     NaN
# 3                NaN    False     NaN     NaN
# 4                NaN    False     NaN     NaN
#
#                                   PRE_FILLED_PATTERN  \
# 0  ELIZABETH LATIF , Law Offices of For <LITIGANT...
# 1  For <STATE_NAME=Alabama> Department of Public ...
# 2  For <LITIGANT_PERSON> , Secretary of U . S . D...
# 3  For <LITIGANT_PERSON> , Acting Commissioner , ...
# 4  For <LITIGATN_PERSON> , Commissioner of Social...
#
#                                        Sentence_TEXT Sentence_ID
# 0  ELIZABETH LATIF , Law Offices of For Defendant...         S29
# 1  For Alabama Department of Public Health , Denn...        S132
# 2  For ALEX M . AZAR II , Secretary of U . S . De...        S135
# 3  For Andrew M . Saul , Acting Commissioner , So...        S136
# 4  For Andrew M . Saul , Commissioner of Social S...        S138

# %%
NER_DF.set_index('EntityCode', inplace = True)
NER_DICT = NER_DF.to_dict(orient='index')
print(NER_DICT['ATTORNEY'])
NER_DF.head()
# Out:
# {'Category': 'Attorney', 'EntityTag': 'attorney', 'isSupported': True, 'Example': nan, 'DictionaryFileName': 'US_attorney_names.xlsx', 'ToDo': nan}
#                    Category EntityTag  isSupported Example DictionaryFileName  \
# EntityCode
# LITIGANT_PERSON    Litigant  litigant        False     NaN  US_litigants.xlsx
# LITIGANT_COMPANY   Litigant  litigant        False     NaN  US_litigants.xlsx
# LITIGANT_COUNTY    Litigant  litigant        False     NaN  US_litigants.xlsx
# LITIGANT_CHURCH    Litigant  litigant        False     NaN  US_litigants.xlsx
# LITIGANT_HOSPITAL  Litigant  litigant        False     NaN  US_litigants.xlsx
#
#                   ToDo
# EntityCode
# LITIGANT_PERSON    NaN
# LITIGANT_COMPANY   NaN
# LITIGANT_COUNTY    NaN
# LITIGANT_CHURCH    NaN
# LITIGANT_HOSPITAL  NaN

# %%
print(MODEL_PATTERN_DF.columns)
# Out:
# Index(['PID', 'Reviewed', 'SME', 'isSpecial', 'DataError',
#        'ExceptionEntityName', 'ExceptionEntityTag', 'isFinal', 'GroupID',
#        'PATTERN', 'PRE_FILLED_PATTERN', 'Sentence_TEXT', 'Sentence_ID'],
#       dtype='object')

# %%
ROI_COLUMNS = ['isSpecial', 'ExceptionEntityName', 'ExceptionEntityTag', 
               'GroupID','PATTERN']
ERROR_PATTERN_DF = MODEL_PATTERN_DF [MODEL_PATTERN_DF.isFinal == True][ROI_COLUMNS]
print(ERROR_PATTERN_DF.shape)
# Out:
# (303, 5)

# %%
#ROI_COLUMNS_2 = ['Reviewed', 'SME', 'DataError', 
#               'isSpecial', 'ExceptionEntityName', 'ExceptionEntityTag', 
#               'GroupID','PATTERN', 'Sentence_TEXT']
#ERROR_PATTERN_DF = MODEL_PATTERN_DF [MODEL_PATTERN_DF.isFinal == True][ROI_COLUMNS_2]
#print(ERROR_PATTERN_DF.shape)

# %%
ERROR_PATTERN_DF.drop_duplicates(inplace = True, ignore_index = True)
print(ERROR_PATTERN_DF.shape)
# Out:
# (266, 5)

# %%
ERROR_PATTERN_DF.head()
# Out:
#    isSpecial ExceptionEntityName ExceptionEntityTag GroupID  \
# 0      False                 NaN                NaN     G18
# 1      False                 NaN                NaN     G13
# 2      False                 NaN                NaN     G13
# 3      False                 NaN                NaN     G13
# 4      False                 NaN                NaN     G13
#
#                                              PATTERN
# 0   Attorney General <ATTORNEY_1> , by Special De...
# 1  <ATTORNEY_1> ,  county attorney , and <ATTORNE...
# 2  <ATTORNEY_1> , <ATTORNEY_2> , <ATTORNEY_3> , D...
# 3  <ATTORNEY_1> , <ATTORNEY_2> , Chief Counsel , ...
# 4  <ATTORNEY_1> , <GOV_TITLE_1> , <ATTORNEY_2> , ...

# %%
UNIQUE_PATTERN_LIST = ERROR_PATTERN_DF.PATTERN.unique()
print(len(UNIQUE_PATTERN_LIST))
# Out:
# 257

# %%
# Process Unambiguous patterns
NON_SPECIAL_PATTERN_DF = ERROR_PATTERN_DF[ERROR_PATTERN_DF.isSpecial == False]
SPECIAL_PATTERN_DF = ERROR_PATTERN_DF[ERROR_PATTERN_DF.isSpecial == True]
NON_SPECIAL_PATTERN_DF.columns
# Out:
# Index(['isSpecial', 'ExceptionEntityName', 'ExceptionEntityTag', 'GroupID',
#        'PATTERN'],
#       dtype='object')

# %%
print(NON_SPECIAL_PATTERN_DF.shape)
print(SPECIAL_PATTERN_DF.shape)
# Out:
# (204, 5)
# (62, 5)

# %%
# Examine the patterns
#special_pattern_list = SPECIAL_PATTERN_DF.PATTERN.unique()
#non_special_pattern_list = NON_SPECIAL_PATTERN_DF.PATTERN.unique()

#print('Non-Special Error Patterns:')
#print_list(non_special_pattern_list)
#print('-'*50)
#print('Special Error Patterns:')
#print_list(special_pattern_list)

# %%
print(PATTERN_GROUP_LIST)
# Out:
# ['G1', 'G2', 'G3', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'G11', 'G12', 'G13', 'G14', 'G15', 'G16', 'G17', 'G18', 'G19', 'G20', 'G21', 'G22', 'G23', 'G24', 'G25', 'G26']

# %%
# Comment PATTERN_GROUP_LIST here, once debugging is finished
#PATTERN_GROUP_LIST = ['G14', 'G15', 'G16', 'G17', 'G18', 'G19', 'G20', 'G21', 'G22', 'G23', 'G24']
CONLL = True
pattern_sent_dict_non_spec = process_non_special_patterns(pg_list = PATTERN_GROUP_LIST, 
                                                          merge = False, 
                                                          pattern_src = "cl_counsel", conll=CONLL)
print("COMPLETED NON-SPECIAL PATTERNS")

#-------------------------
pattern_sent_dict_special = process_special_patterns(pg_list = PATTERN_GROUP_LIST, 
                                                     merge = False, 
                                                     pattern_src = "cl_counsel", conll=CONLL)
print("COMPLETED SPECIAL PATTERNS")
# Out:
# 26  : The Number of Pattern Groups to Process.
# ==================================================
# G1 : Processing this pattern group
# G1 : The Number of Unique Patterns :  5
# HOW MANY =  144
# ==============================
# G1 :  0 : PATTERN TEMPLATE:
# 	 <LITIGANT_PERSON> , in pro . Per. for <LITIGANT_ROLE> .
# ------------------------------
# [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('in', 'other'), ('pro', 'other'), ('.', 'other'), ('Per', 'other'), ('.', 'other'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 0 	NER TOKEN LIST:  [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('in', 'other'), ('pro', 'other'), ('.', 'other'), ('Per', 'other'), ('.', 'other'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G1_cl_counsel_train_iobes.txt
# 0 	 G1_cl_counsel_val_iobes.txt
# 0 	 G1_cl_counsel_test_iobes.txt
# ==============================
# G1 :  1 : PATTERN TEMPLATE:
# 	 <LITIGANT_PERSON> , In pro per , and <ATTORNEY> ,  under appointment by the Court of Appeal , for <LITIGANT_ROLE>  .
# ------------------------------
# [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('In', 'other'), ('pro', 'other'), ('per', 'other'), (',', 'other'), ('and', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('under', 'other'), ('appointment', 'other'), ('by', 'other'), ('the', 'other'), ('Court', 'other'), ('of', 'other'), ('Appeal', 'other'), (',', 'other'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 1 	NER TOKEN LIST:  [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('In', 'other'), ('pro', 'other'), ('per', 'other'), (',', 'other'), ('and', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('under', 'other'), ('appointment', 'other'), ('by', 'other'), ('the', 'other'), ('Court', 'other'), ('of', 'other'), ('Appeal', 'other'), (',', 'other'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 1 	Preparing CONLL file format for writing...
# 1 	 G1_cl_counsel_train_iobes.txt
# 1 	 G1_cl_counsel_val_iobes.txt
# 1 	 G1_cl_counsel_test_iobes.txt
# ==============================
# G1 :  2 : PATTERN TEMPLATE:
# 	 <LITIGANT_PERSON> , in pro Per.
# ------------------------------
# [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('in', 'other'), ('pro', 'other'), ('Per', 'other'), ('.', 'other')]
# 2 	NER TOKEN LIST:  [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('in', 'other'), ('pro', 'other'), ('Per', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 2 	Preparing CONLL file format for writing...
# 2 	 G1_cl_counsel_train_iobes.txt
# 2 	 G1_cl_counsel_val_iobes.txt
# 2 	 G1_cl_counsel_test_iobes.txt
# ==============================
# G1 :  3 : PATTERN TEMPLATE:
# 	 <LITIGANT_PERSON> , in proper person .
# ------------------------------
# [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('in', 'other'), ('proper', 'other'), ('person', 'other'), ('.', 'other')]
# 3 	NER TOKEN LIST:  [('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('in', 'other'), ('proper', 'other'), ('person', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 3 	Preparing CONLL file format for writing...
# 3 	 G1_cl_counsel_train_iobes.txt
# 3 	 G1_cl_counsel_val_iobes.txt
# 3 	 G1_cl_counsel_test_iobes.txt
# ==============================
# G1 :  4 : PATTERN TEMPLATE:
# 	 Counsel for co - defendant <LITIGANT_PERSON> : <LAW_FIRM> ( No papers submitted on the motion ) .
# ------------------------------
# [('Counsel', 'other'), ('for', 'other'), ('co', 'other'), ('-', 'other'), ('defendant', 'other'), ('LITIGANT_PERSON', 'litigant'), (':', 'other'), ('LAW_FIRM', 'lawFirm'), ('(', 'other'), ('No', 'other'), ('papers', 'other'), ('submitted', 'other'), ('on', 'other'), ('the', 'other'), ('motion', 'other'), (')', 'other'), ('.', 'other')]
# 4 	NER TOKEN LIST:  [('Counsel', 'other'), ('for', 'other'), ('co', 'other'), ('-', 'other'), ('defendant', 'other'), ('LITIGANT_PERSON', 'litigant'), (':', 'other'), ('LAW_FIRM', 'lawFirm'), ('(', 'other'), ('No', 'other'), ('papers', 'other'), ('submitted', 'other'), ('on', 'other'), ('the', 'other'), ('motion', 'other'), (')', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 4 	Preparing CONLL file format for writing...
# 4 	 G1_cl_counsel_train_iobes.txt
# 4 	 G1_cl_counsel_val_iobes.txt
# 4 	 G1_cl_counsel_test_iobes.txt
# ==================================================
# G2 : Processing this pattern group
# G2 : The Number of Unique Patterns :  43
# HOW MANY =  144
# ==============================
# G2 :  0 : PATTERN TEMPLATE:
# 	 <ATTORNEY> , Attorney at Law , Anchorage , under contract with the GOVT_ORG_AS_LAW_FIRM , for the <LITIGANT_ROLE> .
# ------------------------------
# [('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('Anchorage', 'other'), (',', 'other'), ('under', 'other'), ('contract', 'other'), ('with', 'other'), ('the', 'other'), ('GOVT_ORG_AS_LAW_FIRM', 'other'), (',', 'other'), ('for', 'other'), ('the', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 0 	NER TOKEN LIST:  [('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('Anchorage', 'other'), (',', 'other'), ('under', 'other'), ('contract', 'other'), ('with', 'other'), ('the', 'other'), ('GOVT_ORG_AS_LAW_FIRM', 'other'), (',', 'other'), ('for', 'other'), ('the', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G2_cl_counsel_train_iobes.txt
# 0 	 G2_cl_counsel_val_iobes.txt
# 0 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  1 : PATTERN TEMPLATE:
# 	 For <LITIGANT_COMPANY> , <LITIGANT_ROLE> : <ATTORNEY> , LEAD ATTORNEY , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 1 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 1 	Preparing CONLL file format for writing...
# 1 	 G2_cl_counsel_train_iobes.txt
# 1 	 G2_cl_counsel_val_iobes.txt
# 1 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  2 : PATTERN TEMPLATE:
# 	 For <LITIGANT_COMPANY> : <ATTORNEY_1> , ESQ . , <STATE_NAME_1> Bar No . 8276 ; <ATTORNEY_2> , ESQ . , <STATE_NAME_1> Bar . No . 8215 ; <ATTORNEY_3> ESQ . , <STATE_NAME_1> Bar No . 11015 , <LAW_FIRM> , <CITY> , <STATE_NAME_1> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('ESQ', 'other'), ('.', 'other'), (',', 'other'), ('STATE_NAME_1', 'state'), ('Bar', 'other'), ('No', 'other'), ('.', 'other'), ('8276', 'other'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('ESQ', 'other'), ('.', 'other'), (',', 'other'), ('STATE_NAME_1', 'state'), ('Bar', 'other'), ('.', 'other'), ('No', 'other'), ('.', 'other'), ('8215', 'other'), (';', 'other'), ('ATTORNEY_3', 'attorney'), ('ESQ', 'other'), ('.', 'other'), (',', 'other'), ('STATE_NAME_1', 'state'), ('Bar', 'other'), ('No', 'other'), ('.', 'other'), ('11015', 'other'), (',', 'other'), ('LAW_FIRM', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME_1', 'state'), ('.', 'other')]
# 2 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('ESQ', 'other'), ('.', 'other'), (',', 'other'), ('STATE_NAME_1', 'state'), ('Bar', 'other'), ('No', 'other'), ('.', 'other'), ('8276', 'other'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('ESQ', 'other'), ('.', 'other'), (',', 'other'), ('STATE_NAME_1', 'state'), ('Bar', 'other'), ('.', 'other'), ('No', 'other'), ('.', 'other'), ('8215', 'other'), (';', 'other'), ('ATTORNEY_3', 'attorney'), ('ESQ', 'other'), ('.', 'other'), (',', 'other'), ('STATE_NAME_1', 'state'), ('Bar', 'other'), ('No', 'other'), ('.', 'other'), ('11015', 'other'), (',', 'other'), ('LAW_FIRM', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME_1', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 2 	Preparing CONLL file format for writing...
# 2 	 G2_cl_counsel_train_iobes.txt
# 2 	 G2_cl_counsel_val_iobes.txt
# 2 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  3 : PATTERN TEMPLATE:
# 	 For <LITIGANT_PERSON> , <LITIGANT_ROLE> : <ATTORNEY_1> , LEAD ATTORNEY , <ATTORNEY_1> Attorney at Law PLLC , <CITY_1> , <STATE_1> ; <ATTORNEY_2> , <GOVT_ORG_AS_LAW_FIRM> - <CITY> , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('ATTORNEY_1', 'attorney'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), ('PLLC', 'other'), (',', 'other'), ('CITY_1', 'city'), (',', 'other'), ('STATE_1', 'state'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('GOVT_ORG_AS_LAW_FIRM', 'lawFirm'), ('-', 'other'), ('CITY', 'city'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 3 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('ATTORNEY_1', 'attorney'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), ('PLLC', 'other'), (',', 'other'), ('CITY_1', 'city'), (',', 'other'), ('STATE_1', 'state'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('GOVT_ORG_AS_LAW_FIRM', 'lawFirm'), ('-', 'other'), ('CITY', 'city'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 3 	Preparing CONLL file format for writing...
# 3 	 G2_cl_counsel_train_iobes.txt
# 3 	 G2_cl_counsel_val_iobes.txt
# 3 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  4 : PATTERN TEMPLATE:
# 	 For <LITIGANT_PERSON> , <LITIGANT_ROLE> : <ATTORNEY> , LEAD ATTORNEY , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 4 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 4 	Preparing CONLL file format for writing...
# 4 	 G2_cl_counsel_train_iobes.txt
# 4 	 G2_cl_counsel_val_iobes.txt
# 4 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  5 : PATTERN TEMPLATE:
# 	 For <LITIGANT_PERSON> , <LITIGANT_ROLE> : <ATTORNEY>, LEAD ATTORNEY , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 5 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 5 	Preparing CONLL file format for writing...
# 5 	 G2_cl_counsel_train_iobes.txt
# 5 	 G2_cl_counsel_val_iobes.txt
# 5 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  6 : PATTERN TEMPLATE:
# 	 For <LITIGANT_PERSON> , aka <PERSON> , <LITIGANT_ROLE> : <ATTORNEY_1> , LEAD ATTORNEY , <LAW_FIRM> , <CITY> , <STATE> ; <ATTORNEY_2> , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('aka', 'other'), ('PERSON', 'person'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('LAW_FIRM', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 6 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('aka', 'other'), ('PERSON', 'person'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('LAW_FIRM', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 6 	Preparing CONLL file format for writing...
# 6 	 G2_cl_counsel_train_iobes.txt
# 6 	 G2_cl_counsel_val_iobes.txt
# 6 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  7 : PATTERN TEMPLATE:
# 	 For <LITIGANT_ROLE> ( s ) : <ATTORNEY> , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), ('(', 'other'), ('s', 'other'), (')', 'other'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 7 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), ('(', 'other'), ('s', 'other'), (')', 'other'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 7 	Preparing CONLL file format for writing...
# 7 	 G2_cl_counsel_train_iobes.txt
# 7 	 G2_cl_counsel_val_iobes.txt
# 7 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  8 : PATTERN TEMPLATE:
# 	 For <LITIGANT_ROLE> : <ATTORNEY_1> , <GOVT_ORG_AS_LAW_FIRM> , <ATTORNEY_2> , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('GOVT_ORG_AS_LAW_FIRM', 'lawFirm'), (',', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 8 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('GOVT_ORG_AS_LAW_FIRM', 'lawFirm'), (',', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 8 	Preparing CONLL file format for writing...
# 8 	 G2_cl_counsel_train_iobes.txt
# 8 	 G2_cl_counsel_val_iobes.txt
# 8 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  9 : PATTERN TEMPLATE:
# 	 For <LITIGANT_ROLE> : <ATTORNEY> , Attorney at Law ,<CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 9 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 9 	Preparing CONLL file format for writing...
# 9 	 G2_cl_counsel_train_iobes.txt
# 9 	 G2_cl_counsel_val_iobes.txt
# 9 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  10 : PATTERN TEMPLATE:
# 	 For <LITIGANT_ROLE> : Prosecuting Attorney <COUNTY> , <COUNTY> Pros . Atty , <CITY> , <STATE> ; <ATTORNEY> , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('Prosecuting', 'other'), ('Attorney', 'other'), ('COUNTY', 'county'), (',', 'other'), ('COUNTY', 'county'), ('Pros', 'other'), ('.', 'other'), ('Atty', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), (';', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 10 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('Prosecuting', 'other'), ('Attorney', 'other'), ('COUNTY', 'county'), (',', 'other'), ('COUNTY', 'county'), ('Pros', 'other'), ('.', 'other'), ('Atty', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), (';', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 10 	Preparing CONLL file format for writing...
# 10 	 G2_cl_counsel_train_iobes.txt
# 10 	 G2_cl_counsel_val_iobes.txt
# 10 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  11 : PATTERN TEMPLATE:
# 	 Justice <ATTORNEY> , Attorney at Law , For K2 Asia Ventures .
# ------------------------------
# [('Justice', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('K2', 'other'), ('Asia', 'other'), ('Ventures', 'other'), ('.', 'other')]
# 11 	NER TOKEN LIST:  [('Justice', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('K2', 'other'), ('Asia', 'other'), ('Ventures', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 11 	Preparing CONLL file format for writing...
# 11 	 G2_cl_counsel_train_iobes.txt
# 11 	 G2_cl_counsel_val_iobes.txt
# 11 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  12 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <COUNTY> .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('COUNTY', 'county'), ('.', 'other')]
# 12 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('COUNTY', 'county'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 12 	Preparing CONLL file format for writing...
# 12 	 G2_cl_counsel_train_iobes.txt
# 12 	 G2_cl_counsel_val_iobes.txt
# 12 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  13 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <COUNTY> County .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('COUNTY', 'county'), ('County', 'other'), ('.', 'other')]
# 13 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('COUNTY', 'county'), ('County', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 13 	Preparing CONLL file format for writing...
# 13 	 G2_cl_counsel_train_iobes.txt
# 13 	 G2_cl_counsel_val_iobes.txt
# 13 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  14 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_COMPANY> , et al .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 14 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 14 	Preparing CONLL file format for writing...
# 14 	 G2_cl_counsel_train_iobes.txt
# 14 	 G2_cl_counsel_val_iobes.txt
# 14 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  15 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_COMPANY> et al .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 15 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 15 	Preparing CONLL file format for writing...
# 15 	 G2_cl_counsel_train_iobes.txt
# 15 	 G2_cl_counsel_val_iobes.txt
# 15 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  16 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_HOSPITAL> .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL', 'litigant'), ('.', 'other')]
# 16 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 16 	Preparing CONLL file format for writing...
# 16 	 G2_cl_counsel_train_iobes.txt
# 16 	 G2_cl_counsel_val_iobes.txt
# 16 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  17 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_HOSPITAL> Hospital Authority .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL', 'litigant'), ('Hospital', 'other'), ('Authority', 'other'), ('.', 'other')]
# 17 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL', 'litigant'), ('Hospital', 'other'), ('Authority', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 17 	Preparing CONLL file format for writing...
# 17 	 G2_cl_counsel_train_iobes.txt
# 17 	 G2_cl_counsel_val_iobes.txt
# 17 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  18 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_INSURANCE_CO> , et al .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_INSURANCE_CO', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 18 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_INSURANCE_CO', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 18 	Preparing CONLL file format for writing...
# 18 	 G2_cl_counsel_train_iobes.txt
# 18 	 G2_cl_counsel_val_iobes.txt
# 18 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  19 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_INSURANCE_CO> .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_INSURANCE_CO', 'litigant'), ('.', 'other')]
# 19 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_INSURANCE_CO', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 19 	Preparing CONLL file format for writing...
# 19 	 G2_cl_counsel_train_iobes.txt
# 19 	 G2_cl_counsel_val_iobes.txt
# 19 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  20 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_LAW_FIRM> , et al .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_LAW_FIRM', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 20 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_LAW_FIRM', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 20 	Preparing CONLL file format for writing...
# 20 	 G2_cl_counsel_train_iobes.txt
# 20 	 G2_cl_counsel_val_iobes.txt
# 20 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  21 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_LAW_FIRM> et al .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_LAW_FIRM', 'litigant'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 21 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_LAW_FIRM', 'litigant'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 21 	Preparing CONLL file format for writing...
# 21 	 G2_cl_counsel_train_iobes.txt
# 21 	 G2_cl_counsel_val_iobes.txt
# 21 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  22 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_PERSON> ( aka <PERSON> ) .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('(', 'other'), ('aka', 'other'), ('PERSON', 'person'), (')', 'other'), ('.', 'other')]
# 22 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('(', 'other'), ('aka', 'other'), ('PERSON', 'person'), (')', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 22 	Preparing CONLL file format for writing...
# 22 	 G2_cl_counsel_train_iobes.txt
# 22 	 G2_cl_counsel_val_iobes.txt
# 22 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  23 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_PERSON> ( Lender ) .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('(', 'other'), ('Lender', 'other'), (')', 'other'), ('.', 'other')]
# 23 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('(', 'other'), ('Lender', 'other'), (')', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 23 	Preparing CONLL file format for writing...
# 23 	 G2_cl_counsel_train_iobes.txt
# 23 	 G2_cl_counsel_val_iobes.txt
# 23 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  24 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_PERSON> , et al .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 24 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 24 	Preparing CONLL file format for writing...
# 24 	 G2_cl_counsel_train_iobes.txt
# 24 	 G2_cl_counsel_val_iobes.txt
# 24 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  25 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <LITIGANT_PERSON> .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('.', 'other')]
# 25 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 25 	Preparing CONLL file format for writing...
# 25 	 G2_cl_counsel_train_iobes.txt
# 25 	 G2_cl_counsel_val_iobes.txt
# 25 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  26 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <STATE_NAME> Restaurant and Lodging Association .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('STATE_NAME', 'state'), ('Restaurant', 'other'), ('and', 'other'), ('Lodging', 'other'), ('Association', 'other'), ('.', 'other')]
# 26 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('STATE_NAME', 'state'), ('Restaurant', 'other'), ('and', 'other'), ('Lodging', 'other'), ('Association', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 26 	Preparing CONLL file format for writing...
# 26 	 G2_cl_counsel_train_iobes.txt
# 26 	 G2_cl_counsel_val_iobes.txt
# 26 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  27 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For <STATE> Hospital Association .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('STATE', 'state'), ('Hospital', 'other'), ('Association', 'other'), ('.', 'other')]
# 27 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('STATE', 'state'), ('Hospital', 'other'), ('Association', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 27 	Preparing CONLL file format for writing...
# 27 	 G2_cl_counsel_train_iobes.txt
# 27 	 G2_cl_counsel_val_iobes.txt
# 27 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  28 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For County of <COUNTY> .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('County', 'other'), ('of', 'other'), ('COUNTY', 'county'), ('.', 'other')]
# 28 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('County', 'other'), ('of', 'other'), ('COUNTY', 'county'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 28 	Preparing CONLL file format for writing...
# 28 	 G2_cl_counsel_train_iobes.txt
# 28 	 G2_cl_counsel_val_iobes.txt
# 28 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  29 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For K2 Asia Ventures .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('K2', 'other'), ('Asia', 'other'), ('Ventures', 'other'), ('.', 'other')]
# 29 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('K2', 'other'), ('Asia', 'other'), ('Ventures', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 29 	Preparing CONLL file format for writing...
# 29 	 G2_cl_counsel_train_iobes.txt
# 29 	 G2_cl_counsel_val_iobes.txt
# 29 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  30 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY> , Attorney at Law , For Trustee .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('Trustee', 'other'), ('.', 'other')]
# 30 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('Trustee', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 30 	Preparing CONLL file format for writing...
# 30 	 G2_cl_counsel_train_iobes.txt
# 30 	 G2_cl_counsel_val_iobes.txt
# 30 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  31 : PATTERN TEMPLATE:
# 	 Mr . <ATTORNEY>, Attorney at Law , For <LITIGANT_COMPANY> , et al .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 31 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 31 	Preparing CONLL file format for writing...
# 31 	 G2_cl_counsel_train_iobes.txt
# 31 	 G2_cl_counsel_val_iobes.txt
# 31 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  32 : PATTERN TEMPLATE:
# 	 Mr . Peter J . Juran , Attorney at Law , For K2 Asia Ventures .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('Peter', 'other'), ('J', 'other'), ('.', 'other'), ('Juran', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('K2', 'other'), ('Asia', 'other'), ('Ventures', 'other'), ('.', 'other')]
# 32 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('Peter', 'other'), ('J', 'other'), ('.', 'other'), ('Juran', 'other'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('K2', 'other'), ('Asia', 'other'), ('Ventures', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 32 	Preparing CONLL file format for writing...
# 32 	 G2_cl_counsel_train_iobes.txt
# 32 	 G2_cl_counsel_val_iobes.txt
# 32 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  33 : PATTERN TEMPLATE:
# 	 Mr .<ATTORNEY> , Attorney at Law , For Executive Office Park of <COUNTY> Association , Inc .
# ------------------------------
# [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('Executive', 'other'), ('Office', 'other'), ('Park', 'other'), ('of', 'other'), ('COUNTY', 'county'), ('Association', 'other'), (',', 'other'), ('Inc', 'other'), ('.', 'other')]
# 33 	NER TOKEN LIST:  [('Mr', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('Executive', 'other'), ('Office', 'other'), ('Park', 'other'), ('of', 'other'), ('COUNTY', 'county'), ('Association', 'other'), (',', 'other'), ('Inc', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 33 	Preparing CONLL file format for writing...
# 33 	 G2_cl_counsel_train_iobes.txt
# 33 	 G2_cl_counsel_val_iobes.txt
# 33 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  34 : PATTERN TEMPLATE:
# 	 Ms . <ATTORNEY> , Attorney at Law , For <LITIGANT_COMPANY> , et al .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 34 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 34 	Preparing CONLL file format for writing...
# 34 	 G2_cl_counsel_train_iobes.txt
# 34 	 G2_cl_counsel_val_iobes.txt
# 34 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  35 : PATTERN TEMPLATE:
# 	 Ms . <ATTORNEY> , Attorney at Law , For <LITIGANT_COMPANY> .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), ('.', 'other')]
# 35 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_COMPANY', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 35 	Preparing CONLL file format for writing...
# 35 	 G2_cl_counsel_train_iobes.txt
# 35 	 G2_cl_counsel_val_iobes.txt
# 35 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  36 : PATTERN TEMPLATE:
# 	 Ms . <ATTORNEY> , Attorney at Law , For <LITIGANT_FOUNDATION> , et al .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_FOUNDATION', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 36 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_FOUNDATION', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 36 	Preparing CONLL file format for writing...
# 36 	 G2_cl_counsel_train_iobes.txt
# 36 	 G2_cl_counsel_val_iobes.txt
# 36 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  37 : PATTERN TEMPLATE:
# 	 Ms . <ATTORNEY> , Attorney at Law , For <LITIGANT_HOSPITAL_1> , d / b / a <LITIGANT_HOSPITAL_2> .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL_1', 'litigant'), (',', 'other'), ('d', 'other'), ('/', 'other'), ('b', 'other'), ('/', 'other'), ('a', 'other'), ('LITIGANT_HOSPITAL_2', 'litigant'), ('.', 'other')]
# 37 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL_1', 'litigant'), (',', 'other'), ('d', 'other'), ('/', 'other'), ('b', 'other'), ('/', 'other'), ('a', 'other'), ('LITIGANT_HOSPITAL_2', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 37 	Preparing CONLL file format for writing...
# 37 	 G2_cl_counsel_train_iobes.txt
# 37 	 G2_cl_counsel_val_iobes.txt
# 37 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  38 : PATTERN TEMPLATE:
# 	 Ms . <ATTORNEY> , Attorney at Law , For <LITIGANT_HOSPITAL>  .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL', 'litigant'), ('.', 'other')]
# 38 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_HOSPITAL', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 38 	Preparing CONLL file format for writing...
# 38 	 G2_cl_counsel_train_iobes.txt
# 38 	 G2_cl_counsel_val_iobes.txt
# 38 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  39 : PATTERN TEMPLATE:
# 	 Ms . <ATTORNEY> , Attorney at Law , For <LITIGANT_PERSON> .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('.', 'other')]
# 39 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('LITIGANT_PERSON', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 39 	Preparing CONLL file format for writing...
# 39 	 G2_cl_counsel_train_iobes.txt
# 39 	 G2_cl_counsel_val_iobes.txt
# 39 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  40 : PATTERN TEMPLATE:
# 	 Ms . <ATTORNEY> , Attorney at Law , For The <LITIGANT_INSURANCE_CO> , et al .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('The', 'other'), ('LITIGANT_INSURANCE_CO', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 40 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('The', 'other'), ('LITIGANT_INSURANCE_CO', 'litigant'), (',', 'other'), ('et', 'other'), ('al', 'other'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 40 	Preparing CONLL file format for writing...
# 40 	 G2_cl_counsel_train_iobes.txt
# 40 	 G2_cl_counsel_val_iobes.txt
# 40 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  41 : PATTERN TEMPLATE:
# 	 Ms .<ATTORNEY> , Attorney at Law , For County of <COUNTY> .
# ------------------------------
# [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('County', 'other'), ('of', 'other'), ('COUNTY', 'county'), ('.', 'other')]
# 41 	NER TOKEN LIST:  [('Ms', 'other'), ('.', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('For', 'other'), ('County', 'other'), ('of', 'other'), ('COUNTY', 'county'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 41 	Preparing CONLL file format for writing...
# 41 	 G2_cl_counsel_train_iobes.txt
# 41 	 G2_cl_counsel_val_iobes.txt
# 41 	 G2_cl_counsel_test_iobes.txt
# ==============================
# G2 :  42 : PATTERN TEMPLATE:
# 	 Physicians for Informed Consent , Other : <ATTORNEY> , Attorney at Law , <CITY> , <STATE> .
# ------------------------------
# [('Physicians', 'other'), ('for', 'other'), ('Informed', 'other'), ('Consent', 'other'), (',', 'other'), ('Other', 'other'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 42 	NER TOKEN LIST:  [('Physicians', 'other'), ('for', 'other'), ('Informed', 'other'), ('Consent', 'other'), (',', 'other'), ('Other', 'other'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('at', 'other'), ('Law', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 42 	Preparing CONLL file format for writing...
# 42 	 G2_cl_counsel_train_iobes.txt
# 42 	 G2_cl_counsel_val_iobes.txt
# 42 	 G2_cl_counsel_test_iobes.txt
# ==================================================
# G3 : Processing this pattern group
# G3 : The Number of Unique Patterns :  0
# HOW MANY =  144
# ==================================================
# G4 : Processing this pattern group
# G4 : The Number of Unique Patterns :  5
# HOW MANY =  144
# ...
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {29: ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm')}
# 0 	NER TOKEN LIST:  [('ATTORNEY_1', 'attorney'), (',', 'other'), ('GOV_TITLE', 'employmentTitle'), (',', 'other'), ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME', 'state'), (',', 'other'), ('for', 'other'), ('Amicus', 'other'), ('State', 'other'), ('of', 'other'), ('STATE_NAME', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G13_cl_counsel_train_iobes.txt
# 0 	 G13_cl_counsel_val_iobes.txt
# 0 	 G13_cl_counsel_test_iobes.txt
# ==============================
# G13 :  1 : PATTERN TEMPLATE:
# 	 <ATTORNEY> ,  OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME> , <CITY> , <STATE_NAME> , for <LITIGANT_ROLE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {14: ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm')}
# 1 	NER TOKEN LIST:  [('ATTORNEY', 'attorney'), (',', 'other'), ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME', 'state'), (',', 'other'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 1 	Preparing CONLL file format for writing...
# 1 	 G13_cl_counsel_train_iobes.txt
# 1 	 G13_cl_counsel_val_iobes.txt
# 1 	 G13_cl_counsel_test_iobes.txt
# ==============================
# G13 :  2 : PATTERN TEMPLATE:
# 	 <ATTORNEY> , <GOV_TITLE> , OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME> , <CITY> , <STATE_NAME> , for Amicus State of <STATE_NAME> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {27: ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm')}
# 2 	NER TOKEN LIST:  [('ATTORNEY', 'attorney'), (',', 'other'), ('GOV_TITLE', 'employmentTitle'), (',', 'other'), ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME', 'state'), (',', 'other'), ('for', 'other'), ('Amicus', 'other'), ('State', 'other'), ('of', 'other'), ('STATE_NAME', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 2 	Preparing CONLL file format for writing...
# 2 	 G13_cl_counsel_train_iobes.txt
# 2 	 G13_cl_counsel_val_iobes.txt
# 2 	 G13_cl_counsel_test_iobes.txt
# ==================================================
# G14 : Processing this pattern group
# G14 : The Number of Unique Patterns :  1
# HOW MANY =  144
# ==============================
# G14 :  0 : PATTERN TEMPLATE:
# 	 <ODD_LAW_FIRM> and <ATTORNEY_1> ; <PERSON_LAST_NAME> LAW , <ATTORNEY_2> and <ATTORNEY_3>  for <LITIGANT_ROLE> and <LITIGANT_ROLE> <LITIGANT_COMPANY> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {}
# 0 	NER TOKEN LIST:  [('ODD_LAW_FIRM', 'lawFirm'), ('and', 'other'), ('ATTORNEY_1', 'attorney'), (';', 'other'), ('PERSON_LAST_NAME', 'person'), ('LAW', 'other'), (',', 'other'), ('ATTORNEY_2', 'attorney'), ('and', 'other'), ('ATTORNEY_3', 'attorney'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('and', 'other'), ('LITIGANT_ROLE', 'litigant'), ('LITIGANT_COMPANY', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G14_cl_counsel_train_iobes.txt
# 0 	 G14_cl_counsel_val_iobes.txt
# 0 	 G14_cl_counsel_test_iobes.txt
# ==================================================
# G15 : Processing this pattern group
# G15 : The Number of Unique Patterns :  0
# HOW MANY =  144
# ==================================================
# G16 : Processing this pattern group
# G16 : The Number of Unique Patterns :  0
# HOW MANY =  144
# ==================================================
# G17 : Processing this pattern group
# G17 : The Number of Unique Patterns :  0
# HOW MANY =  144
# ==================================================
# G18 : Processing this pattern group
# G18 : The Number of Unique Patterns :  3
# HOW MANY =  144
# ==============================
# G18 :  0 : PATTERN TEMPLATE:
# 	 <ATTORNEY_1>, Attorney General , OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME> , <CITY> , <STATE_NAME> , for Amicus State of <STATE_NAME> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {33: ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm')}
# 0 	NER TOKEN LIST:  [('ATTORNEY_1', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('General', 'other'), (',', 'other'), ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME', 'state'), (',', 'other'), ('for', 'other'), ('Amicus', 'other'), ('State', 'other'), ('of', 'other'), ('STATE_NAME', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G18_cl_counsel_train_iobes.txt
# 0 	 G18_cl_counsel_val_iobes.txt
# 0 	 G18_cl_counsel_test_iobes.txt
# ==============================
# G18 :  1 : PATTERN TEMPLATE:
# 	 <ATTORNEY_1>, Attorney General ,<ATTORNEY_2> , Solicitor General ,  <ATTORNEY_3> , Assistant Attorney General , OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME> , <CITY> , <STATE_NAME> , for <LITIGANT_ROLE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {112: ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm')}
# 1 	NER TOKEN LIST:  [('ATTORNEY_1', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('General', 'other'), (',', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('Solicitor', 'other'), ('General', 'other'), (',', 'other'), ('ATTORNEY_3', 'attorney'), (',', 'other'), ('Assistant', 'other'), ('Attorney', 'other'), ('General', 'other'), (',', 'other'), ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME', 'state'), (',', 'other'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 1 	Preparing CONLL file format for writing...
# 1 	 G18_cl_counsel_train_iobes.txt
# 1 	 G18_cl_counsel_val_iobes.txt
# 1 	 G18_cl_counsel_test_iobes.txt
# ==============================
# G18 :  2 : PATTERN TEMPLATE:
# 	 <ATTORNEY> , Attorney General , OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME> , <CITY> , <STATE_NAME> , for Amicus State of <STATE_NAME> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {32: ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm')}
# 2 	NER TOKEN LIST:  [('ATTORNEY', 'attorney'), (',', 'other'), ('Attorney', 'other'), ('General', 'other'), (',', 'other'), ('OFFICE OF THE ATTORNEY GENERAL OF <STATE_NAME>', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME', 'state'), (',', 'other'), ('for', 'other'), ('Amicus', 'other'), ('State', 'other'), ('of', 'other'), ('STATE_NAME', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 2 	Preparing CONLL file format for writing...
# 2 	 G18_cl_counsel_train_iobes.txt
# 2 	 G18_cl_counsel_val_iobes.txt
# 2 	 G18_cl_counsel_test_iobes.txt
# ==================================================
# G19 : Processing this pattern group
# G19 : The Number of Unique Patterns :  1
# HOW MANY =  144
# ==============================
# G19 :  0 : PATTERN TEMPLATE:
# 	 <STATE_NAME> Attorney General ' s Office , <CITY> , By <ATTORNEY> , Counsel for <LITIGANT_ROLE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {0: ("<STATE_NAME> Attorney General ' s Office", 'lawFirm')}
# 0 	NER TOKEN LIST:  [("<STATE_NAME> Attorney General ' s Office", 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('By', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('Counsel', 'other'), ('for', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G19_cl_counsel_train_iobes.txt
# 0 	 G19_cl_counsel_val_iobes.txt
# 0 	 G19_cl_counsel_test_iobes.txt
# ==================================================
# G20 : Processing this pattern group
# G20 : The Number of Unique Patterns :  0
# HOW MANY =  144
# ==================================================
# G21 : Processing this pattern group
# G21 : The Number of Unique Patterns :  1
# HOW MANY =  144
# ==============================
# G21 :  0 : PATTERN TEMPLATE:
# 	 For <LITIGANT_ROLE> : <ATTORNEY> , SBN : 24052152 , <PERSON_LAST_NAME> LAW , <CITY> , <STATE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {}
# 0 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('SBN', 'other'), (':', 'other'), ('24052152', 'other'), (',', 'other'), ('PERSON_LAST_NAME', 'person'), ('LAW', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G21_cl_counsel_train_iobes.txt
# 0 	 G21_cl_counsel_val_iobes.txt
# 0 	 G21_cl_counsel_test_iobes.txt
# ==================================================
# G22 : Processing this pattern group
# G22 : The Number of Unique Patterns :  0
# HOW MANY =  144
# ==================================================
# G23 : Processing this pattern group
# G23 : The Number of Unique Patterns :  2
# HOW MANY =  144
# ==============================
# G23 :  0 : PATTERN TEMPLATE:
# 	 For <STATE_NAME> Department of Medicaid , <LITIGANT_ROLE> : <ATTORNEY> , LEAD ATTORNEY , Office of the <STATE_NAME> Attorney General , Collections Enforcement , <CITY> , <STATE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {89: ('Office of the <STATE_NAME> Attorney General , Collections Enforcement', 'lawFirm')}
# 0 	NER TOKEN LIST:  [('For', 'other'), ('STATE_NAME', 'state'), ('Department', 'other'), ('of', 'other'), ('Medicaid', 'other'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('Office of the <STATE_NAME> Attorney General , Collections Enforcement', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G23_cl_counsel_train_iobes.txt
# 0 	 G23_cl_counsel_val_iobes.txt
# 0 	 G23_cl_counsel_test_iobes.txt
# ==============================
# G23 :  1 : PATTERN TEMPLATE:
# 	 For Office of the Attorney General , Interested Party : <ATTORNEY> , LEAD ATTORNEY , State of  <STATE_NAME> , Office of the Attorney General , <CITY> , <STATE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {85: ('State of  <STATE_NAME> , Office of the Attorney General', 'lawFirm')}
# 1 	NER TOKEN LIST:  [('For', 'other'), ('Office', 'other'), ('of', 'other'), ('the', 'other'), ('Attorney', 'other'), ('General', 'other'), (',', 'other'), ('Interested', 'other'), ('Party', 'other'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('State of  <STATE_NAME> , Office of the Attorney General', 'lawFirm'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 1 	Preparing CONLL file format for writing...
# 1 	 G23_cl_counsel_train_iobes.txt
# 1 	 G23_cl_counsel_val_iobes.txt
# 1 	 G23_cl_counsel_test_iobes.txt
# ==================================================
# G24 : Processing this pattern group
# G24 : The Number of Unique Patterns :  2
# HOW MANY =  144
# ==============================
# G24 :  0 : PATTERN TEMPLATE:
# 	 For State : <ATTORNEY_1> , CRIMINAL DISTRICT ATTORNEY ; <ATTORNEY_2> , CHIEF OF APPELLATE DIVISION , ASSISTANT CRIMINAL DISTRICT ATTORNEY ; <ATTORNEY_3> , ASSISTANT CRIMINAL DISTRICT ATTORNEY , <COUNTY> COUNTY DISTRICT ATTORNEY ’ S OFFICE <CITY> , <STATE_NAME> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {}
# 0 	NER TOKEN LIST:  [('For', 'other'), ('State', 'other'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('CRIMINAL', 'other'), ('DISTRICT', 'other'), ('ATTORNEY', 'other'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('CHIEF', 'other'), ('OF', 'other'), ('APPELLATE', 'other'), ('DIVISION', 'other'), (',', 'other'), ('ASSISTANT', 'other'), ('CRIMINAL', 'other'), ('DISTRICT', 'other'), ('ATTORNEY', 'other'), (';', 'other'), ('ATTORNEY_3', 'attorney'), (',', 'other'), ('ASSISTANT', 'other'), ('CRIMINAL', 'other'), ('DISTRICT', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ('COUNTY', 'county'), ('COUNTY', 'other'), ('DISTRICT', 'other'), ('ATTORNEY', 'other'), ('’', 'other'), ('S', 'other'), ('OFFICE', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE_NAME', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G24_cl_counsel_train_iobes.txt
# 0 	 G24_cl_counsel_val_iobes.txt
# 0 	 G24_cl_counsel_test_iobes.txt
# ==============================
# G24 :  1 : PATTERN TEMPLATE:
# 	 For The City of <CITY_1> , a government entity , <LITIGANT_ROLE> : <ATTORNEY_1> , LEAD ATTORNEY , <CITY_1> City Attorney ' s Office , <CITY_1> , <STATE_1> ; <ATTORNEY_2> , <CITY_1> City Attorneys Office , <CITY_1> , <STATE_1> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {98: ("<CITY_1> City Attorney ' s Office", 'lawFirm')}
# 1 	NER TOKEN LIST:  [('For', 'other'), ('The', 'other'), ('City', 'other'), ('of', 'other'), ('CITY_1', 'city'), (',', 'other'), ('a', 'other'), ('government', 'other'), ('entity', 'other'), (',', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY_1', 'attorney'), (',', 'other'), ('LEAD', 'other'), ('ATTORNEY', 'other'), (',', 'other'), ("<CITY_1> City Attorney ' s Office", 'lawFirm'), (',', 'other'), ('CITY_1', 'city'), (',', 'other'), ('STATE_1', 'state'), (';', 'other'), ('ATTORNEY_2', 'attorney'), (',', 'other'), ('CITY_1', 'city'), ('City', 'other'), ('Attorneys', 'other'), ('Office', 'other'), (',', 'other'), ('CITY_1', 'city'), (',', 'other'), ('STATE_1', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 1 	Preparing CONLL file format for writing...
# 1 	 G24_cl_counsel_train_iobes.txt
# 1 	 G24_cl_counsel_val_iobes.txt
# 1 	 G24_cl_counsel_test_iobes.txt
# ==================================================
# G25 : Processing this pattern group
# G25 : The Number of Unique Patterns :  2
# HOW MANY =  144
# ==============================
# G25 :  0 : PATTERN TEMPLATE:
# 	 <PERSON_LAST_NAME> LAW , <CITY>  ( <ATTORNEY_1> OF COUNSEL ) , FOR <LITIGANT_ROLE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {}
# 0 	NER TOKEN LIST:  [('PERSON_LAST_NAME', 'person'), ('LAW', 'other'), (',', 'other'), ('CITY', 'city'), ('(', 'other'), ('ATTORNEY_1', 'attorney'), ('OF', 'other'), ('COUNSEL', 'other'), (')', 'other'), (',', 'other'), ('FOR', 'other'), ('LITIGANT_ROLE', 'litigant'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 0 	Preparing CONLL file format for writing...
# 0 	 G25_cl_counsel_train_iobes.txt
# 0 	 G25_cl_counsel_val_iobes.txt
# 0 	 G25_cl_counsel_test_iobes.txt
# ==============================
# G25 :  1 : PATTERN TEMPLATE:
# 	 For <LITIGANT_ROLE> : <ATTORNEY> , #26033 , <PERSON_LAST_NAME> LAW , <CITY> , <STATE> .
# ------------------------------
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# {}
# 1 	NER TOKEN LIST:  [('For', 'other'), ('LITIGANT_ROLE', 'litigant'), (':', 'other'), ('ATTORNEY', 'attorney'), (',', 'other'), ('#26033', 'other'), (',', 'other'), ('PERSON_LAST_NAME', 'person'), ('LAW', 'other'), (',', 'other'), ('CITY', 'city'), (',', 'other'), ('STATE', 'state'), ('.', 'other')]
# 144  fake sentences per file and per pattern
# 1 	Preparing CONLL file format for writing...
# 1 	 G25_cl_counsel_train_iobes.txt
# 1 	 G25_cl_counsel_val_iobes.txt
# 1 	 G25_cl_counsel_test_iobes.txt
# ==================================================
# G26 : Processing this pattern group
# G26 : The Number of Unique Patterns :  0
# HOW MANY =  144
# COMPLETED SPECIAL PATTERNS

# %% [markdown]
# ***
# __STOP HERE__

# %%
def get_text(tokenized_sent):
    text = ""
    for entity, tag in tokenized_sent:
        text = text + entity.strip() + ' '
    return text
    
pattern_list = []
sent_list = []
for key, val in pattern_sent_dict_special.items():
    #print(key)
    #print('-'*30)
    for tokenized_sent in val[0:1]:
        sent = get_text(tokenized_sent)
        pattern_list.append(key)
        sent_list.append(sent)
        print(sent)
        print('~'*30)
        
for key, val in pattern_sent_dict_non_spec.items():
    #print(key)
    #print('-'*30)
    for tokenized_sent in val[0:1]:
        sent = get_text(tokenized_sent)
        pattern_list.append(key)
        sent_list.append(sent)
        print(sent)
        print('~'*30)

pattern_sent_df = pd.DataFrame(list(zip(sent_list, pattern_list)))
pattern_sent_df.columns = ['Sentence_TEXT', 'PATTERN']
print(pattern_sent_df.shape)
pattern_sent_df.to_excel("../pattern_sent_examples_4.xlsx")
# Out:
# For State : Mark Boyle , CRIMINAL DISTRICT ATTORNEY ; Rebecca W   Blackmore , CHIEF OF APPELLATE DIVISION , ASSISTANT CRIMINAL DISTRICT ATTORNEY ; John Chamberlain , ASSISTANT CRIMINAL DISTRICT ATTORNEY , MCLEAN COUNTY DISTRICT ATTORNEY ’ S OFFICE JOHNSON LANE , Iowa .
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For The City of SKYLAND ESTATES , a government entity , Defendants - Appellees : Gregory Francis Noonan , LEAD ATTORNEY , HUBBARD City Attorney ' s Office , SKYLAND ESTATES , WY ; JULIE CHRISTINE GREBEL , SKYLAND ESTATES City Attorneys Office , SKYLAND ESTATES , WY .
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# For United States Citizenship and Immigration Services , COUNTERDEFENDANT : TRAVIS E   BURNETT , GOVT , LEAD ATTORNEY , US ATTORNEY ' S OFFICE , TOM BEAN , MA .
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mr . Jason J   George , Assistant Attorney General , For State of West Virginia .
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mr . Lauren Courtney Dimaggio , General Counsel , For NATIONSTAR MORTGAGE LLC .
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Mr . Maria D . Medina Monteserin , Special Deputy Attorney General , For State of Texas .
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Ms . Kristin Elizabeth Averill , Special Deputy Attorney General , For State of Minnesota .
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# (7, 2)

# %%
# Save all the Patterns used to Build the model
pattern_file_path = "../PATTERNS/CORPUS_GROUPS/01_GROUP_TEMPLATES_CASE_LAW_1000.xlsx"
ERROR_PATTERN_DF.to_excel(pattern_file_path, sheet_name = "ModelPatterns")
ner_file_path = "../PATTERNS/CORPUS_GROUPS/NamedEntities.xlsx"
NER_DF.to_excel (ner_file_path, sheet_name = "NamedEntities")


#SIZE = 13888
#print('RANDOM_STATE = ', RANDOM_STATE)
print(NON_SPECIAL_PATTERN_DF.shape[0], "\t: Traditional Templates")
print(SPECIAL_PATTERN_DF.shape[0], "\t : Special Templates")
print(len(UNIQUE_PATTERN_LIST), "\t: TOTAL COUNSEL TEMPLATES")
print('-'*30)
#print(SIZE, "\t : Training Data Sentences")
#print(SIZE, "\t : Validation Data Sentences")
#print(SIZE, "\t : Test Data Sentences")
#print(SIZE*3, "\t : TOTAL CORPUS SIZE")
# Out:
# 191 	: Traditional Templates
# 34 	 : Special Templates
# 216 	: TOTAL COUNSEL TEMPLATES
# ------------------------------

# %%
print('-'*30)
print(f'\nEntity Tags Dictionary Keys: \n{ENTITY_CODE_DF_DCT.keys()}')
print('-'*30)
# Out:
# ------------------------------
#
# Entity Tags Dictionary Keys:
# dict_keys(['LITIGANT_PERSON', 'LITIGANT_COMPANY', 'LITIGANT_COUNTY', 'LITIGANT_CHURCH', 'LITIGANT_HOSPITAL', 'LITIGANT_INSURANCE_CO', 'LITIGANT_FOUNDATION', 'LITIGANT_ROLE', 'GOV_LITIGANT', 'LITIGANT_LAW_FIRM', 'ATTORNEY', 'LAW_FIRM', 'ODD_LAW_FIRM', 'GOVT_ORG_AS_LAW_FIRM', 'AMICUS_CURAE_LAW_FIRM', 'FOUNDATION_LAW_FIRM', 'CITY', 'CITY_ABBR', 'STATE', 'STATE_NAME', 'STATE_ABBR', 'COUNTY', 'PERSON', 'PERSON_LAST_NAME', 'GOV_TITLE', 'PRISON', 'CHURCH'])
# ------------------------------

# %%
print('RANDOM_STATE = ', RANDOM_STATE)
#process_non_special_patterns(pg_list = ["G1","G3"], merge = True, pattern_src = "cl_counsel")
# Out:
# RANDOM_STATE =  743

# %%
#process_special_patterns(pg_list = ["G1"], merge = False, pattern_src = "cl_counsel")

# %%
#pattern_group = "G3"
#df = NON_SPECIAL_PATTERN_DF [NON_SPECIAL_PATTERN_DF.GroupID == pattern_group]
#print(df.shape)
#df.head()
